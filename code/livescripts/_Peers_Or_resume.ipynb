# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- peers/or
#
# PS	l	r	mean
# 3
# 	0.095
# 		0.06
# 			mean of results: 0.06757459489251608 (sD)
# 			mean time: 0:02:23.755055 (hh/mm/ss)
# 			n: 5
# 	0.15
# 		0.06
# 			mean of results: 0.06501366633789404 (sD)
# 			mean time: 0:02:33.970903 (hh/mm/ss)
# 			n: 5
