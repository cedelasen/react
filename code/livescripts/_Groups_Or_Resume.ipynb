# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- groups/or
#
# PS	l	r	mean
# 5
# 	0.95
# 		0.03
# 		0.06
# 			mean of results: 0.067495 (sD)
# 			standard deviation: 0.000432
# 			mean time: 0:03:41.563245 (hh/mm/ss)
# 			mean acc/den: 0.906 (%) / 0.094 (%)
# 			n: 10
# 	0.15
# 		0.03
# 			mean of results: 0.066575 (sD)
# 			standard deviation: 0.002216
# 			mean time: 0:00:29.368258 (hh/mm/ss)
# 			mean acc/den: 0.892 (%) / 0.108 (%)
# 			n: 10
# 		0.06
# 			mean of results: 0.067298 (sD)
# 			standard deviation: 0.001073
# 			mean time: 0:00:14.958717 (hh/mm/ss)
# 			mean acc/den: 0.895 (%) / 0.105 (%)
# 			n: 10
# 	0.095
# 		0.03
# 			mean of results: 0.067572 (sD)
# 			standard deviation: 0.000285
# 			mean time: 0:00:27.319656 (hh/mm/ss)
# 			mean acc/den: 0.89 (%) / 0.11 (%)
# 			n: 10
# 		0.06
# 			mean of results: 0.067045 (sD)
# 			standard deviation: 0.000794
# 			mean time: 0:00:13.882258 (hh/mm/ss)
# 			mean acc/den: 0.885 (%) / 0.115 (%)
# 			n: 10
