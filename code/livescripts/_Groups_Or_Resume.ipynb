# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- groups/or
#
# PS	l	r	mean
# 3
# 	0.095
# 		0.06
# 			mean of results: 0.06873184664248114 (sD)
# 			mean time: 0:02:23.281250 (hh/mm/ss)
# 			n: 5
# 	0.15
# 		0.06
# 			mean of results: 0.06728972888006446 (sD)
# 			mean time: 0:02:14.283721 (hh/mm/ss)
# 			n: 5
