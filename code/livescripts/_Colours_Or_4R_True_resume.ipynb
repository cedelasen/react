# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- colours/or/4rectangles/True
#
# PS	l	r	mean
# 5
# 	0.15
# 		0.03
# 			mean of results: 0.067396 (sD)
# 			standard deviation: 0.000512
# 			mean time: 0:00:40.009387 (hh/mm/ss)
# 			mean acc/den: 1.0 (%) / 0.0 (%)
# 			n: 10
# 		0.06
# 			mean of results: 0.067703 (sD)
# 			standard deviation: 5.4e-05
# 			mean time: 0:00:19.934495 (hh/mm/ss)
# 			mean acc/den: 1.0 (%) / 0.0 (%)
# 			n: 10
# 	0.95
# 		0.03
# 		0.06
# 			mean of results: 0.067398 (sD)
# 			standard deviation: 0.001013
# 			mean time: 0:04:54.966030 (hh/mm/ss)
# 			mean acc/den: 1.0 (%) / 0.0 (%)
# 			n: 10
# 	0.095
# 		0.03
# 			mean of results: 0.067684 (sD)
# 			standard deviation: 0.000105
# 			mean time: 0:00:35.709531 (hh/mm/ss)
# 			mean acc/den: 1.0 (%) / 0.0 (%)
# 			n: 10
# 		0.06
# 			mean of results: 0.067231 (sD)
# 			standard deviation: 0.00125
# 			mean time: 0:00:18.601504 (hh/mm/ss)
# 			mean acc/den: 1.0 (%) / 0.0 (%)
# 			n: 10
