# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- colours/and/random2colours/True
#
# PS	l	r	mean
# 3
# 	0.15
# 		0.06
# 			mean of results: 0.06928528937171544 (sD)
# 			mean time: 0:02:27.756164 (hh/mm/ss)
# 			n: 2
# 	0.095
# 		0.06
# 			mean of results: 0.06928528937171544 (sD)
# 			mean time: 0:02:27.726605 (hh/mm/ss)
# 			n: 2
