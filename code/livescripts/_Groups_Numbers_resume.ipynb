# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- groups/numbers
#
# PS	l	r	mean
# 3
# 	0.095
# 		0.06
# 			mean of results: 0.050667975767055305 (sD)
# 			mean time: 0:02:14.404537 (hh/mm/ss)
# 			n: 10
# 	0.15
# 		0.06
# 			mean of results: 0.0530429750565274 (sD)
# 			mean time: 0:02:02.716224 (hh/mm/ss)
# 			n: 10
