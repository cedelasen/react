# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- colours/numbers/random2colours/True
#
# PS	l	r	mean
# 5
# 	0.95
# 		0.06
# 			mean of results: 0.067382 (sD)
# 			standard deviation: 0.000536
# 			mean time: 0:07:12.392433 (hh/mm/ss)
# 			mean acc/den: 0.997 (%) / 0.003 (%)
# 			n: 10
# 		0.03
# 	0.095
# 		0.06
# 			mean of results: 0.067554 (sD)
# 			standard deviation: 0.000534
# 			mean time: 0:00:26.798451 (hh/mm/ss)
# 			mean acc/den: 0.996 (%) / 0.004 (%)
# 			n: 10
# 		0.03
# 			mean of results: 0.067385 (sD)
# 			standard deviation: 0.001052
# 			mean time: 0:00:51.301574 (hh/mm/ss)
# 			mean acc/den: 0.997 (%) / 0.003 (%)
# 			n: 10
# 	0.15
# 		0.06
# 			mean of results: 0.067371 (sD)
# 			standard deviation: 0.000796
# 			mean time: 0:00:28.850480 (hh/mm/ss)
# 			mean acc/den: 0.997 (%) / 0.003 (%)
# 			n: 10
# 		0.03
# 			mean of results: 0.067165 (sD)
# 			standard deviation: 0.001118
# 			mean time: 0:00:56.125736 (hh/mm/ss)
# 			mean acc/den: 0.998 (%) / 0.002 (%)
# 			n: 10
