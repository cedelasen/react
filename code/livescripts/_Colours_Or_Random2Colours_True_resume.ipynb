# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- colours/or/random2colours/True
#
# PS	l	r	mean
# 5
# 	0.15
# 		0.06
# 			mean of results: 0.067407 (sD)
# 			standard deviation: 0.000938
# 			mean time: 0:00:20.276174 (hh/mm/ss)
# 			mean acc/den: 1.0 (%) / 0.0 (%)
# 			n: 10
# 		0.03
# 			mean of results: 0.066991 (sD)
# 			standard deviation: 0.001062
# 			mean time: 0:00:39.439859 (hh/mm/ss)
# 			mean acc/den: 1.0 (%) / 0.0 (%)
# 			n: 10
# 	0.095
# 		0.06
# 			mean of results: 0.067501 (sD)
# 			standard deviation: 0.000482
# 			mean time: 0:00:18.660949 (hh/mm/ss)
# 			mean acc/den: 1.0 (%) / 0.0 (%)
# 			n: 10
# 		0.03
# 			mean of results: 0.067704 (sD)
# 			standard deviation: 6.5e-05
# 			mean time: 0:00:36.489687 (hh/mm/ss)
# 			mean acc/den: 1.0 (%) / 0.0 (%)
# 			n: 10
# 	0.95
# 		0.06
# 			mean of results: 0.06773 (sD)
# 			standard deviation: 1.3e-05
# 			mean time: 0:04:57.548754 (hh/mm/ss)
# 			mean acc/den: 1.0 (%) / 0.0 (%)
# 			n: 10
# 		0.03
