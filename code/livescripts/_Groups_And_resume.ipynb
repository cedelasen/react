# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- groups/and
#
# PS	l	r	mean
# 3
# 	0.15
# 		0.06
# 			mean of results: 0.06185422813813701 (sD)
# 			mean time: 0:02:14.164740 (hh/mm/ss)
# 			n: 10
# 	0.095
# 		0.06
# 			mean of results: 0.06312044626579832 (sD)
# 			mean time: 0:02:13.412816 (hh/mm/ss)
# 			n: 10
