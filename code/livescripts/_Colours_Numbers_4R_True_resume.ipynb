# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- colours/numbers/4rectangles/True
#
# PS	l	r	mean
# 3
# 	0.15
# 		0.06
# 			mean of results: 0.06928528937171544 (sD)
# 			mean time: 0:02:42.209877 (hh/mm/ss)
# 			n: 2
# 	0.095
# 		0.06
# 			mean of results: 0.06928528937171544 (sD)
# 			mean time: 0:02:28.528401 (hh/mm/ss)
# 			n: 2
