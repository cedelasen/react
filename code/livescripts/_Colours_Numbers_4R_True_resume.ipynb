# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- colours/numbers/4rectangles/True
#
# PS	l	r	mean
# 5
# 	0.95
# 		0.06
# 			mean of results: 0.06756 (sD)
# 			standard deviation: 0.000517
# 			mean time: 0:07:07.470074 (hh/mm/ss)
# 			mean acc/den: 0.994 (%) / 0.006 (%)
# 			n: 10
# 		0.03
# 	0.095
# 		0.06
# 			mean of results: 0.067411 (sD)
# 			standard deviation: 0.000872
# 			mean time: 0:00:26.509647 (hh/mm/ss)
# 			mean acc/den: 0.992 (%) / 0.008 (%)
# 			n: 10
# 		0.03
# 			mean of results: 0.067459 (sD)
# 			standard deviation: 0.000572
# 			mean time: 0:00:50.298437 (hh/mm/ss)
# 			mean acc/den: 0.993 (%) / 0.007 (%)
# 			n: 10
# 	0.15
# 		0.06
# 			mean of results: 0.067462 (sD)
# 			standard deviation: 0.000765
# 			mean time: 0:00:28.193392 (hh/mm/ss)
# 			mean acc/den: 0.992 (%) / 0.008 (%)
# 			n: 10
# 		0.03
# 			mean of results: 0.067491 (sD)
# 			standard deviation: 0.000737
# 			mean time: 0:00:56.931096 (hh/mm/ss)
# 			mean acc/den: 0.994 (%) / 0.006 (%)
# 			n: 10
