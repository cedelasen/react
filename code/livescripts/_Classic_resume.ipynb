# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- classic
#
# PS	l	r	mean
# 3
# 	0.095
# 		0.06
# 			mean of results: 0.04706496442225865 (sD)
# 			mean time: 0:02:13.496569 (hh/mm/ss)
# 			n: 10
# 	0.15
# 		0.06
# 			mean of results: 0.047815959254386156 (sD)
# 			mean time: 0:02:11.366667 (hh/mm/ss)
# 			n: 10
