# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- peers/or
#
# PS	l	r	mean
# 3
# 	0.095
# 		0.06
# 			mean of results: 0.06448944783803653 (sD)
# 			mean time: 0:02:08.754155 (hh/mm/ss)
# 			n: 10
# 	0.15
# 		0.06
# 			mean of results: 0.060905957686423415 (sD)
# 			mean time: 0:02:07.554203 (hh/mm/ss)
# 			n: 10
