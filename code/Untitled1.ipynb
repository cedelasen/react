# %%
import main; main
# Out:
# Ejecutando PLANTING SEEDS
# Ejecutando PLANTING SEEDS CONT
# Ejecutando SIMULATED ANNEALING GROUPS OR METHOD
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-0519dc1e676a> in <module>
# ----> 1 import main; main
#
# /app/main.py in <module>
#      88   execute(args)
#      89
# ---> 90 main()
#
# /app/main.py in main()
#      86 def main():
#      87   args = process_args()
# ---> 88   execute(args)
#      89
#      90 main()
#
# /app/main.py in execute(args)
#      52       #execution.execute(args.l, args.r, args.maxExecs, args.minR, args.maxR, args.relationship, args.method, args.colourDistribution, args.static, imagePath)
#      53
# ---> 54       bestPSet, bestSD = execution.execute(args.l, args.r, args.maxExecs, args.minR, args.maxR, args.relationship, args.method, args.colourDistribution, args.static, imagePath)
#      55
# ...
