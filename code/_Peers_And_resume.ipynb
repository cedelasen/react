# %%
import dataProcessing; dataProcessing.resumeResults()
# Out:
# Resume of results -- peers/and
#
# PS	l	r	mean
# 3
# 	0.15
# 		0.06
# 			mean of results: 0.05391242023535812 (sD)
# 			mean time: 0:02:21.738390 (hh/mm/ss)
# 			n: 10
# 	0.095
# 		0.06
# 			mean of results: 0.053500717767422434 (sD)
# 			mean time: 0:02:12.546899 (hh/mm/ss)
# 			n: 10
